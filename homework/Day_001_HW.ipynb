# %% [markdown]
# # 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 1. 你選的這組資料為何重要
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 這組資料想解決的問題如何評估
#
# 答：
# 選取比賽主題為：Histopathologic Cancer Detection
# https://www.kaggle.com/c/histopathologic-cancer-detection/overview
# 1.	我選擇這個主題，主要是病理切片辨識技術可以透過大數據的方式去自動找出可能癌症病灶的區域，除了自動化，減低醫師主觀的人為誤差，更能從辨識病灶區域的特徵中找出更多獨特新發現的病灶區域。
# 2.	來自於PatchCamelyon (PCam)的benchmark dataset的改編版本，蒐集了臨床試驗淋巴組織切片的顯微鏡影像圖片檔集，類似CIFAR10專案，主要用來作為機器學習的訓練與測試資料使用，資料大小大但也可透過單一個GPU就能計算。
# 3.	共有三種資料。第一個sample_submission為樣本資料型態為切片資訊各個病灶樣本與正常樣本的圖片id列表檔。另一個train_labels.csv記載著訓練組內每一個切片的標註id內容，涵蓋id和label兩欄資料。最後zip檔裡面分成訓練組與測試組，裡面包含每個id的病灶tif格式圖檔。針對positive(有病灶)的圖檔為32x32 px區域大小的圖片，裡面會涵蓋至少1 pixel的癌症組織區域。
# 4.	透過建立一個演算法去辨識病理切片，可以透過大數據的方式去自動找出可能癌症病灶的區域。

# %% [markdown]
# # 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 答：
# 1.	核心問題是透過既有得資料去預測一個數學模式，假設藉此改變各種變因(Xi)來預測如何提升特定因素達到提升整體的業績(Yi)。
# 2.	因為是自由載客車隊，資料有很多類型，包含影響到價錢的載客時間、移動距離、最短距離、載客客人類型、客源分布單位人口面積、是否為尖峰時間、是否為離峰時間、優惠方案等都是變因之一，資料來源可以是自由載客車隊裡的收據資料、透過GPS紀錄每次移動的網路地圖、區域人口活動分布面積資料等來著手。這些資料可能造成我的假設無法均一，會變成多變因的影響。
# 3.	針對收據資料為文字檔資訊，主要包含時間、移動距離兩連續資料等。GPS記載資料為移動距離、時間等連續資料、起始點與終點之離散資料與圖片(pixel)的陣列資料。客源分布單位人口面積可以包含人口面積、區域圖片與區域等離散資料。
# 4.	評估在建構模型的情況下，載客區域選擇那些區域與時間，以及歸納載客移動距離是能夠達到最大載客收益。

# %% [markdown]
# ## 作業3-練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y-yp)**2)/len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 219.433
# The Mean absolute error is 12.137
